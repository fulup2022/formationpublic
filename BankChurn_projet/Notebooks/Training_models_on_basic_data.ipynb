# %% [markdown]
# # 1.First we get the data

# %%
# First we map the drive to access the data file
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# We load the data file in a pandas dataframe
import pandas as pd
dataset = pd.read_csv('/content/drive/MyDrive/DSTI/Churn/Bank churn/Bank_churn_dataset.csv')
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# # 2.Data exploration and features analysis

# %%
# We check the shape of the dataset and the columns names
print(f"Shape = {dataset.shape}")
print(f"The names of the columns = {dataset.columns}")
print(f"The range of the index = {dataset.index}")
# Out:
# Shape = (10000, 14)
# The names of the columns = Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')
# The range of the index = RangeIndex(start=0, stop=10000, step=1)

# %%
# Another way to get a summary of the dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# We check if there is some Nan in the dataset
dataset.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# we check the data ventilation for the different features
dataset.describe(include='all')
# Out:
#           RowNumber    CustomerId Surname   CreditScore Geography Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000     10000  10000
# unique          NaN           NaN    2932           NaN         3      2
# top             NaN           NaN   Smith           NaN    France   Male
# freq            NaN           NaN      32           NaN      5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800       NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299       NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000       NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000       NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000       NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000       NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000       NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# count   10000.000000  10000.000000   10000.000000   10000.000000  10000.00000
# unique           NaN           NaN            NaN            NaN          NaN
# top              NaN           NaN            NaN            NaN          NaN
# freq             NaN           NaN            NaN            NaN          NaN
# mean       38.921800      5.012800   76485.889288       1.530200      0.70550
# std        10.487806      2.892174   62397.405202       0.581654      0.45584
# min        18.000000      0.000000       0.000000       1.000000      0.00000
# 25%        32.000000      3.000000       0.000000       1.000000      0.00000
# 50%        37.000000      5.000000   97198.540000       1.000000      1.00000
# 75%        44.000000      7.000000  127644.240000       2.000000      1.00000
# max        92.000000     10.000000  250898.090000       4.000000      1.00000
#
#         IsActiveMember  EstimatedSalary        Exited
# count     10000.000000     10000.000000  10000.000000
# unique             NaN              NaN           NaN
# top                NaN              NaN           NaN
# freq               NaN              NaN           NaN
# mean          0.515100    100090.239881      0.203700
# std           0.499797     57510.492818      0.402769
# min           0.000000        11.580000      0.000000
# 25%           0.000000     51002.110000      0.000000
# 50%           1.000000    100193.915000      0.000000
# 75%           1.000000    149388.247500      0.000000
# max           1.000000    199992.480000      1.000000

# %% [markdown]
# We notice that there are only 2932 distinct surnames among the 10 000 data samples. We can deduce that it is not a real dataset since it seems doubtful that there are so few names shared by all the clients.
#
# We have two genders with a good repartition between males and females.
#
# For the exited values, we can notice that there are around 20% of clients who have churned. It means that we have unbalanced data and it will be necessary to handle this aspect.

# %%
dataset.Exited.value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %% [markdown]
# There is maybe something to do about this point since we are in the presence of unbalanced data.

# %%
# We take our features in a  new dataset. 
# We exclude the three first columns of the original dataset since they are too specific and the last one since it is the label
df = dataset.iloc[:, 3:]
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# Analysis of the different features types present in the dataset
numerical_features = ['CreditScore',  'Age', 'Tenure', 'Balance','NumOfProducts', 'EstimatedSalary']
categorical_features = ['HasCrCard', 'IsActiveMember','Geography', 'Gender']
label = ['Exited']

# %%
# For the different categorical features, we check the possible values
for c in categorical_features:
  print(df.groupby(c)[c].size())
  print (' ')
# Out:
# HasCrCard
# 0    2945
# 1    7055
# Name: HasCrCard, dtype: int64
#
# IsActiveMember
# 0    4849
# 1    5151
# Name: IsActiveMember, dtype: int64
#
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64
#
# Gender
# Female    4543
# Male      5457
# Name: Gender, dtype: int64

# %%
# we copy the data to make some analysis without modifying the original dataset
df_analysis = df.copy()
df_analysis.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# For the categorical features that are in string format, we replace the values by a corresponding integer in order to be able to calulate a correlation with other features for these values
df_analysis.Geography = df_analysis.Geography.map({'France' : 0, 'Germany' : 1, 'Spain' : 2})
df_analysis.Gender = df_analysis.Gender.map({'Female' : 0, 'Male' : 1})

# %%
df_analysis.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       0   42       2       0.00              1
# 1          608          2       0   41       1   83807.86              1
# 2          502          0       0   42       8  159660.80              3
# 3          699          0       0   39       1       0.00              2
# 4          850          2       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# calculate the correlation matrix
import seaborn as sns
import matplotlib.pyplot as plt

f = plt.figure(figsize = (12,12))
sns.set()
sns.heatmap(df_analysis.corr().round(2), annot = True, cmap = "Blues")

# %% [markdown]
# **So we notice that there is no correlation between the different features, and there is sense to keep them all.**

# %% [markdown]
# # 3.Split of the data in train/test and preparing the automatic data transformation

# %% [markdown]
# In this section, we will split the data between the training and the test datasets. We will also create the pipeline to standardize data in order to make the models more effective.

# %%
# we make the data split between train and test
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size = 0.2, random_state = 1)

# %%
print(f"The shape of train : {df_train.shape}")
print(f"The shape of test : {df_test.shape}")
# Out:
# The shape of train : (8000, 11)
# The shape of test : (2000, 11)

# %%
df_train_x = df_train.iloc[:,:-1]
df_train_y = df_train.iloc[:,-1]
df_test_x = df_test.iloc[:,:-1]
df_test_y = df_test.iloc[:,-1]

# %%
df_train_x.head()
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 2694          628   Germany    Male   29       3  113146.98              2
# 5140          626    France  Female   29       4  105767.28              2
# 2568          612   Germany  Female   47       6  130024.87              1
# 3671          646   Germany  Female   52       6  111739.40              2
# 7427          714     Spain    Male   33       8  122017.19              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 2694          0               1        124749.08
# 5140          0               0         41104.82
# 2568          1               1         45750.21
# 3671          0               1         68367.18
# 7427          0               0        162515.17

# %%
# we prepare the transformation operations on numerical features and string features in pipelines in order to be able to apply the same transformations for the future model in prediction
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.impute import SimpleImputer

numerical_pipeline = make_pipeline(SimpleImputer(), StandardScaler())

categorical_pipeline = make_pipeline(SimpleImputer(strategy = 'most_frequent'), OrdinalEncoder())

# %%
# we include the transformation operations into a single column transformer. Each transformation applies to the corresponding features
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder

preprocessor = make_column_transformer((numerical_pipeline, numerical_features), (categorical_pipeline, categorical_features))

# %%
# test of the automatic transformations
preprocessor.fit_transform(df_train_x)
# Out:
# array([[-0.23082038, -0.94449979, -0.70174202, ...,  1.        ,
#          1.        ,  1.        ],
#        [-0.25150912, -0.94449979, -0.35520275, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.3963303 ,  0.77498705,  0.33787579, ...,  1.        ,
#          1.        ,  0.        ],
#        ...,
#        [ 0.22433188,  0.58393295,  1.3774936 , ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.13123255,  0.01077067,  1.03095433, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 1.1656695 ,  0.29735181,  0.33787579, ...,  0.        ,
#          1.        ,  1.        ]])

# %% [markdown]
# # 4.Trying several models

# %%
# we have to install scikeras to be able to use the neural network model
# !pip install scikeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikeras
#   Downloading scikeras-0.9.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: importlib-metadata>=3 in /usr/local/lib/python3.7/dist-packages (from scikeras) (4.13.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from scikeras) (1.0.2)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.7/dist-packages (from scikeras) (21.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3->scikeras) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3->scikeras) (3.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=0.21->scikeras) (3.0.9)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.21.6)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->scikeras) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.2.0)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.9.0

# %%
# we declare the path to the specific_modules.py folder in order to be able to load it
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/projet')

# %%
# we import one specific class ModelWrapper and one specific function model_nn that will be used for the models processing
from specific_modules import ModelWrapper, model_nn

# %%
# we initialize the list of models we will use
list_of_models = []

# %% [markdown]
# ## 4.1.Model 1 : XGBClassifier

# %%
# we try the XGB model with a GridSearchCV to optimize the hyper parameters
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier

param_xgb_grid = {'max_depth': [5,6,7,8], 'gamma': [0.01,0.001],'min_child_weight':[1,5,10], 'learning_rate': [0.05,0.1,0.2], 'n_estimators':[5,10]}
xgb_grid = GridSearchCV(XGBClassifier(), param_grid = param_xgb_grid, cv=5, refit=True, verbose=0)

model1 = ModelWrapper(base_preprocessor=preprocessor, base_model=xgb_grid, tag='XGBClassifier trained on basic data')

# %%
model1.fit(df_train_x, df_train_y)
# Out:
# Tag : 'XGBClassifier trained on basic data'
# Model name : GridSearchCV(cv=5, estimator=XGBClassifier(),
#              param_grid={'gamma': [0.01, 0.001],
#                          'learning_rate': [0.05, 0.1, 0.2],
#                          'max_depth': [5, 6, 7, 8],
#                          'min_child_weight': [1, 5, 10],
#                          'n_estimators': [5, 10]})
# Best estimator : XGBClassifier(gamma=0.01, learning_rate=0.2, max_depth=6, n_estimators=10)
# Best score : 0.8612500000000001

# %%
modele1_training_analysis = pd.DataFrame(model1.named_steps['model'].cv_results_)
modele1_training_analysis.sort_values(by=['mean_test_score'], ascending=False).head()
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time param_gamma  \
# 127       0.088351      0.005822         0.002249        0.000049       0.001
# 55        0.084915      0.003482         0.002404        0.000276        0.01
# 131       0.079892      0.003464         0.002108        0.000261       0.001
# 59        0.079850      0.001463         0.002248        0.000059        0.01
# 49        0.070982      0.005652         0.001907        0.000035        0.01
#
#     param_learning_rate param_max_depth param_min_child_weight  \
# 127                 0.2               6                      1
# 55                  0.2               6                      1
# 131                 0.2               6                     10
# 59                  0.2               6                     10
# 49                  0.2               5                      1
#
#     param_n_estimators                                             params  \
# 127                 10  {'gamma': 0.001, 'learning_rate': 0.2, 'max_de...
# 55                  10  {'gamma': 0.01, 'learning_rate': 0.2, 'max_dep...
# 131                 10  {'gamma': 0.001, 'learning_rate': 0.2, 'max_de...
# 59                  10  {'gamma': 0.01, 'learning_rate': 0.2, 'max_dep...
# 49                  10  {'gamma': 0.01, 'learning_rate': 0.2, 'max_dep...
#
#      split0_test_score  split1_test_score  split2_test_score  \
# 127            0.86875            0.86250           0.855625
# 55             0.86875            0.86250           0.855625
# 131            0.86625            0.86375           0.851250
# 59             0.86625            0.86375           0.851250
# 49             0.86875            0.85875           0.853750
#
#      split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 127           0.861250           0.858125         0.861250        0.004455
# 55            0.861250           0.858125         0.861250        0.004455
# 131           0.858125           0.853750         0.858625        0.005706
# 59            0.858125           0.853750         0.858625        0.005706
# 49            0.859375           0.851250         0.858375        0.006016
#
#      rank_test_score
# 127                1
# 55                 1
# 131                3
# 59                 3
# 49                 5

# %%
model1_predictions = model1.predict(df_test_x)

# %%
model1.evaluate(y_true = df_test_y, y_pred = model1_predictions)
# Out:
# Confusion matrix : array([[1538,   47],
#        [ 233,  182]])
# Precision : 0.7947598253275109
# Accuracy : 0.86
# Recall : 0.43855421686746987

# %%
model1.calculate_roc(y_true = df_test_y, y_score = model1.predict_proba(df_test_x)[:,1])
# Out:
# Roc_auc_score : 0.8692250389570901

# %%
list_of_models.append(model1)

# %% [markdown]
# ## 4.2.Model 2 : Logistic regression

# %%
# Fit logistic regression
from sklearn.linear_model import LogisticRegression

param_logistic_grid = {'C': [0.1,0.5,1,10,50,100], 'max_iter': [250], 'fit_intercept':[True],'intercept_scaling':[1],
              'penalty':['l2'], 'tol':[0.00001,0.0001,0.000001]}
logistic_Grid = GridSearchCV(LogisticRegression(solver='lbfgs'),param_grid = param_logistic_grid, cv = 10, refit=True, verbose=0)

model2 = ModelWrapper(base_preprocessor=preprocessor, base_model = logistic_Grid, tag = 'LogisticRegression trained on basic data')

# %%
model2.fit(df_train_x, df_train_y)
# Out:
# Tag : 'LogisticRegression trained on basic data'
# Model name : GridSearchCV(cv=10, estimator=LogisticRegression(),
#              param_grid={'C': [0.1, 0.5, 1, 10, 50, 100],
#                          'fit_intercept': [True], 'intercept_scaling': [1],
#                          'max_iter': [250], 'penalty': ['l2'],
#                          'tol': [1e-05, 0.0001, 1e-06]})
# Best estimator : LogisticRegression(C=0.5, max_iter=250, tol=1e-05)
# Best score : 0.810125

# %%
model2_predictions = model2.predict(df_test_x)

# %%
model2.evaluate(y_true = df_test_y, y_pred = model2_predictions)
# Out:
# Confusion matrix : array([[1536,   49],
#        [ 339,   76]])
# Precision : 0.608
# Accuracy : 0.806
# Recall : 0.18313253012048192

# %%
model2.calculate_roc(y_true = df_test_y, y_score = model2.predict_proba(df_test_x)[:,1])
# Out:
# Roc_auc_score : 0.7609623351449964

# %%
list_of_models.append(model2)

# %% [markdown]
# ## 4.3.Model 3 : SVM with Pol Kernel

# %%
# Fit SVM
from sklearn.svm import SVC

param_svm_grid = {'C': [0.5,1,10,50,100], 'gamma': [0.1,0.01,0.001],'probability':[True],'kernel': ['poly'],'degree':[2,3] }
svm_Grid = GridSearchCV(SVC(),param_grid = param_svm_grid, cv = 3, refit=True, verbose=0)

model3 = ModelWrapper(base_preprocessor=preprocessor, base_model = svm_Grid, tag = 'SVM trained on basic data')

# %%
model3.fit(df_train_x, df_train_y)
# Out:
# Tag : 'SVM trained on basic data'
# Model name : GridSearchCV(cv=3, estimator=SVC(),
#              param_grid={'C': [0.5, 1, 10, 50, 100], 'degree': [2, 3],
#                          'gamma': [0.1, 0.01, 0.001], 'kernel': ['poly'],
#                          'probability': [True]})
# Best estimator : SVC(C=50, gamma=0.1, kernel='poly', probability=True)
# Best score : 0.8466245732786777

# %%
model3_predictions = model3.predict(df_test_x)

# %%
model3.evaluate(y_true = df_test_y, y_pred = model3_predictions)
# Out:
# Confusion matrix : array([[1567,   18],
#        [ 274,  141]])
# Precision : 0.8867924528301887
# Accuracy : 0.854
# Recall : 0.3397590361445783

# %%
model3.calculate_roc(y_true = df_test_y, y_score = model3.predict_proba(df_test_x)[:,1])
# Out:
# Roc_auc_score : 0.833152673786629

# %%
list_of_models.append(model3)

# %% [markdown]
# ## 4.4.Model 4 : Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

param_rf_grid = {'max_depth': [3, 5, 6, 7, 8], 'max_features': [2,4,6,7,8,9],'n_estimators':[50,100],'min_samples_split': [3, 5, 6, 7]}
rf_grid = GridSearchCV(RandomForestClassifier(), param_grid = param_rf_grid, cv=5, refit=True, verbose=0)

model4 = ModelWrapper(base_preprocessor=preprocessor, base_model=rf_grid, tag = 'RandomForest trained on basic data')

# %%
model4.fit(df_train_x, df_train_y)
# Out:
# Tag : 'RandomForest trained on basic data'
# Model name : GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [3, 5, 6, 7, 8],
#                          'max_features': [2, 4, 6, 7, 8, 9],
#                          'min_samples_split': [3, 5, 6, 7],
#                          'n_estimators': [50, 100]})
# Best estimator : RandomForestClassifier(max_depth=8, max_features=6, min_samples_split=5)
# Best score : 0.8594999999999999

# %%
model4_predictions = model4.predict(df_test_x)

# %%
model4.evaluate(y_true = df_test_y, y_pred = model4_predictions)
# Out:
# Confusion matrix : array([[1545,   40],
#        [ 240,  175]])
# Precision : 0.813953488372093
# Accuracy : 0.86
# Recall : 0.42168674698795183

# %%
model4.calculate_roc(y_true = df_test_y, y_score = model4.predict_proba(df_test_x)[:,1])
# Out:
# Roc_auc_score : 0.8725552050473185

# %%
list_of_models.append(model4)

# %% [markdown]
# ## 4.5.Model 5 : Neural network

# %%
from scikeras.wrappers import KerasClassifier

model5 = ModelWrapper(base_preprocessor=preprocessor, base_model=KerasClassifier(model = model_nn, batch_size=100, verbose = 2).set_params(epochs = 200), tag = 'NeuralNetwork trained on basic data')

# %%
model5.fit(df_train_x, df_train_y)
# Out:
# Epoch 1/200
# 80/80 - 1s - loss: 0.5943 - accuracy: 0.7968 - mean_squared_error: 0.2038 - auc: 0.5389 - 1s/epoch - 15ms/step
# Epoch 2/200
# 80/80 - 0s - loss: 0.4452 - accuracy: 0.7972 - mean_squared_error: 0.1424 - auc: 0.7444 - 145ms/epoch - 2ms/step
# Epoch 3/200
# 80/80 - 0s - loss: 0.4302 - accuracy: 0.8014 - mean_squared_error: 0.1369 - auc: 0.7682 - 143ms/epoch - 2ms/step
# Epoch 4/200
# 80/80 - 0s - loss: 0.4222 - accuracy: 0.8067 - mean_squared_error: 0.1339 - auc: 0.7811 - 147ms/epoch - 2ms/step
# Epoch 5/200
# 80/80 - 0s - loss: 0.4129 - accuracy: 0.8095 - mean_squared_error: 0.1301 - auc: 0.7942 - 146ms/epoch - 2ms/step
# Epoch 6/200
# 80/80 - 0s - loss: 0.4008 - accuracy: 0.8179 - mean_squared_error: 0.1253 - auc: 0.8079 - 144ms/epoch - 2ms/step
# Epoch 7/200
# 80/80 - 0s - loss: 0.3878 - accuracy: 0.8321 - mean_squared_error: 0.1208 - auc: 0.8205 - 142ms/epoch - 2ms/step
# Epoch 8/200
# 80/80 - 0s - loss: 0.3770 - accuracy: 0.8430 - mean_squared_error: 0.1170 - auc: 0.8317 - 153ms/epoch - 2ms/step
# Epoch 9/200
# 80/80 - 0s - loss: 0.3691 - accuracy: 0.8499 - mean_squared_error: 0.1141 - auc: 0.8371 - 152ms/epoch - 2ms/step
# Epoch 10/200
# 80/80 - 0s - loss: 0.3626 - accuracy: 0.8515 - mean_squared_error: 0.1119 - auc: 0.8437 - 167ms/epoch - 2ms/step
# Epoch 11/200
# 80/80 - 0s - loss: 0.3582 - accuracy: 0.8543 - mean_squared_error: 0.1106 - auc: 0.8469 - 139ms/epoch - 2ms/step
# Epoch 12/200
# 80/80 - 0s - loss: 0.3548 - accuracy: 0.8554 - mean_squared_error: 0.1091 - auc: 0.8494 - 142ms/epoch - 2ms/step
# Epoch 13/200
# 80/80 - 0s - loss: 0.3523 - accuracy: 0.8559 - mean_squared_error: 0.1084 - auc: 0.8510 - 141ms/epoch - 2ms/step
# Epoch 14/200
# 80/80 - 0s - loss: 0.3509 - accuracy: 0.8571 - mean_squared_error: 0.1077 - auc: 0.8509 - 140ms/epoch - 2ms/step
# Epoch 15/200
# 80/80 - 0s - loss: 0.3493 - accuracy: 0.8561 - mean_squared_error: 0.1072 - auc: 0.8519 - 138ms/epoch - 2ms/step
# Epoch 16/200
# 80/80 - 0s - loss: 0.3485 - accuracy: 0.8581 - mean_squared_error: 0.1067 - auc: 0.8522 - 150ms/epoch - 2ms/step
# Epoch 17/200
# 80/80 - 0s - loss: 0.3476 - accuracy: 0.8556 - mean_squared_error: 0.1065 - auc: 0.8525 - 130ms/epoch - 2ms/step
# Epoch 18/200
# 80/80 - 0s - loss: 0.3465 - accuracy: 0.8601 - mean_squared_error: 0.1060 - auc: 0.8527 - 152ms/epoch - 2ms/step
# Epoch 19/200
# 80/80 - 0s - loss: 0.3451 - accuracy: 0.8585 - mean_squared_error: 0.1056 - auc: 0.8547 - 142ms/epoch - 2ms/step
# Epoch 20/200
# 80/80 - 0s - loss: 0.3439 - accuracy: 0.8584 - mean_squared_error: 0.1053 - auc: 0.8557 - 139ms/epoch - 2ms/step
# Epoch 21/200
# 80/80 - 0s - loss: 0.3431 - accuracy: 0.8587 - mean_squared_error: 0.1050 - auc: 0.8565 - 156ms/epoch - 2ms/step
# Epoch 22/200
# 80/80 - 0s - loss: 0.3416 - accuracy: 0.8597 - mean_squared_error: 0.1044 - auc: 0.8573 - 133ms/epoch - 2ms/step
# Epoch 23/200
# 80/80 - 0s - loss: 0.3413 - accuracy: 0.8597 - mean_squared_error: 0.1042 - auc: 0.8575 - 161ms/epoch - 2ms/step
# Epoch 24/200
# 80/80 - 0s - loss: 0.3418 - accuracy: 0.8580 - mean_squared_error: 0.1047 - auc: 0.8571 - 146ms/epoch - 2ms/step
# Epoch 25/200
# 80/80 - 0s - loss: 0.3405 - accuracy: 0.8600 - mean_squared_error: 0.1041 - auc: 0.8580 - 145ms/epoch - 2ms/step
# Epoch 26/200
# 80/80 - 0s - loss: 0.3404 - accuracy: 0.8609 - mean_squared_error: 0.1040 - auc: 0.8577 - 150ms/epoch - 2ms/step
# Epoch 27/200
# 80/80 - 0s - loss: 0.3391 - accuracy: 0.8604 - mean_squared_error: 0.1036 - auc: 0.8592 - 159ms/epoch - 2ms/step
# Epoch 28/200
# 80/80 - 0s - loss: 0.3390 - accuracy: 0.8605 - mean_squared_error: 0.1035 - auc: 0.8591 - 133ms/epoch - 2ms/step
# Epoch 29/200
# 80/80 - 0s - loss: 0.3377 - accuracy: 0.8600 - mean_squared_error: 0.1030 - auc: 0.8602 - 153ms/epoch - 2ms/step
# Epoch 30/200
# 80/80 - 0s - loss: 0.3380 - accuracy: 0.8625 - mean_squared_error: 0.1031 - auc: 0.8596 - 144ms/epoch - 2ms/step
# Epoch 31/200
# 80/80 - 0s - loss: 0.3379 - accuracy: 0.8596 - mean_squared_error: 0.1032 - auc: 0.8603 - 127ms/epoch - 2ms/step
# Epoch 32/200
# 80/80 - 0s - loss: 0.3367 - accuracy: 0.8614 - mean_squared_error: 0.1030 - auc: 0.8616 - 139ms/epoch - 2ms/step
# Epoch 33/200
# 80/80 - 0s - loss: 0.3365 - accuracy: 0.8600 - mean_squared_error: 0.1028 - auc: 0.8614 - 138ms/epoch - 2ms/step
# Epoch 34/200
# 80/80 - 0s - loss: 0.3365 - accuracy: 0.8612 - mean_squared_error: 0.1028 - auc: 0.8615 - 135ms/epoch - 2ms/step
# Epoch 35/200
# 80/80 - 0s - loss: 0.3358 - accuracy: 0.8618 - mean_squared_error: 0.1026 - auc: 0.8620 - 130ms/epoch - 2ms/step
# Epoch 36/200
# 80/80 - 0s - loss: 0.3363 - accuracy: 0.8609 - mean_squared_error: 0.1025 - auc: 0.8607 - 140ms/epoch - 2ms/step
# Epoch 37/200
# 80/80 - 0s - loss: 0.3355 - accuracy: 0.8619 - mean_squared_error: 0.1023 - auc: 0.8618 - 151ms/epoch - 2ms/step
# Epoch 38/200
# 80/80 - 0s - loss: 0.3346 - accuracy: 0.8606 - mean_squared_error: 0.1022 - auc: 0.8629 - 140ms/epoch - 2ms/step
# Epoch 39/200
# 80/80 - 0s - loss: 0.3335 - accuracy: 0.8629 - mean_squared_error: 0.1017 - auc: 0.8636 - 159ms/epoch - 2ms/step
# Epoch 40/200
# 80/80 - 0s - loss: 0.3344 - accuracy: 0.8619 - mean_squared_error: 0.1019 - auc: 0.8624 - 153ms/epoch - 2ms/step
# Epoch 41/200
# 80/80 - 0s - loss: 0.3344 - accuracy: 0.8634 - mean_squared_error: 0.1018 - auc: 0.8620 - 155ms/epoch - 2ms/step
# Epoch 42/200
# 80/80 - 0s - loss: 0.3334 - accuracy: 0.8624 - mean_squared_error: 0.1017 - auc: 0.8636 - 138ms/epoch - 2ms/step
# Epoch 43/200
# 80/80 - 0s - loss: 0.3333 - accuracy: 0.8631 - mean_squared_error: 0.1015 - auc: 0.8634 - 162ms/epoch - 2ms/step
# Epoch 44/200
# 80/80 - 0s - loss: 0.3330 - accuracy: 0.8625 - mean_squared_error: 0.1016 - auc: 0.8641 - 157ms/epoch - 2ms/step
# Epoch 45/200
# 80/80 - 0s - loss: 0.3326 - accuracy: 0.8625 - mean_squared_error: 0.1014 - auc: 0.8646 - 142ms/epoch - 2ms/step
# Epoch 46/200
# 80/80 - 0s - loss: 0.3324 - accuracy: 0.8627 - mean_squared_error: 0.1014 - auc: 0.8644 - 144ms/epoch - 2ms/step
# Epoch 47/200
# 80/80 - 0s - loss: 0.3320 - accuracy: 0.8618 - mean_squared_error: 0.1011 - auc: 0.8648 - 134ms/epoch - 2ms/step
# Epoch 48/200
# 80/80 - 0s - loss: 0.3332 - accuracy: 0.8635 - mean_squared_error: 0.1015 - auc: 0.8639 - 141ms/epoch - 2ms/step
# Epoch 49/200
# 80/80 - 0s - loss: 0.3322 - accuracy: 0.8626 - mean_squared_error: 0.1012 - auc: 0.8648 - 148ms/epoch - 2ms/step
# Epoch 50/200
# 80/80 - 0s - loss: 0.3308 - accuracy: 0.8639 - mean_squared_error: 0.1007 - auc: 0.8655 - 138ms/epoch - 2ms/step
# Epoch 51/200
# 80/80 - 0s - loss: 0.3311 - accuracy: 0.8643 - mean_squared_error: 0.1008 - auc: 0.8653 - 136ms/epoch - 2ms/step
# Epoch 52/200
# 80/80 - 0s - loss: 0.3302 - accuracy: 0.8648 - mean_squared_error: 0.1006 - auc: 0.8667 - 135ms/epoch - 2ms/step
# Epoch 53/200
# 80/80 - 0s - loss: 0.3300 - accuracy: 0.8636 - mean_squared_error: 0.1005 - auc: 0.8665 - 136ms/epoch - 2ms/step
# Epoch 54/200
# 80/80 - 0s - loss: 0.3306 - accuracy: 0.8631 - mean_squared_error: 0.1007 - auc: 0.8657 - 131ms/epoch - 2ms/step
# Epoch 55/200
# 80/80 - 0s - loss: 0.3296 - accuracy: 0.8627 - mean_squared_error: 0.1003 - auc: 0.8674 - 132ms/epoch - 2ms/step
# Epoch 56/200
# 80/80 - 0s - loss: 0.3304 - accuracy: 0.8620 - mean_squared_error: 0.1007 - auc: 0.8660 - 139ms/epoch - 2ms/step
# Epoch 57/200
# 80/80 - 0s - loss: 0.3292 - accuracy: 0.8624 - mean_squared_error: 0.1003 - auc: 0.8673 - 149ms/epoch - 2ms/step
# Epoch 58/200
# 80/80 - 0s - loss: 0.3303 - accuracy: 0.8652 - mean_squared_error: 0.1005 - auc: 0.8661 - 148ms/epoch - 2ms/step
# Epoch 59/200
# 80/80 - 0s - loss: 0.3289 - accuracy: 0.8650 - mean_squared_error: 0.1001 - auc: 0.8671 - 143ms/epoch - 2ms/step
# Epoch 60/200
# 80/80 - 0s - loss: 0.3291 - accuracy: 0.8659 - mean_squared_error: 0.1002 - auc: 0.8675 - 159ms/epoch - 2ms/step
# Epoch 61/200
# 80/80 - 0s - loss: 0.3280 - accuracy: 0.8637 - mean_squared_error: 0.0999 - auc: 0.8687 - 146ms/epoch - 2ms/step
# Epoch 62/200
# 80/80 - 0s - loss: 0.3279 - accuracy: 0.8635 - mean_squared_error: 0.0998 - auc: 0.8687 - 166ms/epoch - 2ms/step
# Epoch 63/200
# 80/80 - 0s - loss: 0.3279 - accuracy: 0.8659 - mean_squared_error: 0.0997 - auc: 0.8682 - 145ms/epoch - 2ms/step
# Epoch 64/200
# 80/80 - 0s - loss: 0.3273 - accuracy: 0.8656 - mean_squared_error: 0.0996 - auc: 0.8687 - 145ms/epoch - 2ms/step
# Epoch 65/200
# 80/80 - 0s - loss: 0.3270 - accuracy: 0.8652 - mean_squared_error: 0.0996 - auc: 0.8695 - 149ms/epoch - 2ms/step
# Epoch 66/200
# 80/80 - 0s - loss: 0.3273 - accuracy: 0.8640 - mean_squared_error: 0.0995 - auc: 0.8690 - 141ms/epoch - 2ms/step
# Epoch 67/200
# 80/80 - 0s - loss: 0.3274 - accuracy: 0.8669 - mean_squared_error: 0.0995 - auc: 0.8689 - 136ms/epoch - 2ms/step
# Epoch 68/200
# 80/80 - 0s - loss: 0.3268 - accuracy: 0.8659 - mean_squared_error: 0.0995 - auc: 0.8692 - 135ms/epoch - 2ms/step
# Epoch 69/200
# 80/80 - 0s - loss: 0.3275 - accuracy: 0.8651 - mean_squared_error: 0.0996 - auc: 0.8687 - 137ms/epoch - 2ms/step
# Epoch 70/200
# 80/80 - 0s - loss: 0.3269 - accuracy: 0.8655 - mean_squared_error: 0.0994 - auc: 0.8693 - 144ms/epoch - 2ms/step
# Epoch 71/200
# 80/80 - 0s - loss: 0.3259 - accuracy: 0.8683 - mean_squared_error: 0.0989 - auc: 0.8695 - 161ms/epoch - 2ms/step
# Epoch 72/200
# 80/80 - 0s - loss: 0.3272 - accuracy: 0.8656 - mean_squared_error: 0.0994 - auc: 0.8690 - 143ms/epoch - 2ms/step
# Epoch 73/200
# 80/80 - 0s - loss: 0.3261 - accuracy: 0.8658 - mean_squared_error: 0.0991 - auc: 0.8698 - 141ms/epoch - 2ms/step
# Epoch 74/200
# 80/80 - 0s - loss: 0.3255 - accuracy: 0.8668 - mean_squared_error: 0.0990 - auc: 0.8700 - 144ms/epoch - 2ms/step
# Epoch 75/200
# 80/80 - 0s - loss: 0.3272 - accuracy: 0.8645 - mean_squared_error: 0.0993 - auc: 0.8680 - 165ms/epoch - 2ms/step
# Epoch 76/200
# 80/80 - 0s - loss: 0.3261 - accuracy: 0.8669 - mean_squared_error: 0.0991 - auc: 0.8701 - 142ms/epoch - 2ms/step
# Epoch 77/200
# 80/80 - 0s - loss: 0.3250 - accuracy: 0.8673 - mean_squared_error: 0.0988 - auc: 0.8710 - 146ms/epoch - 2ms/step
# Epoch 78/200
# 80/80 - 0s - loss: 0.3252 - accuracy: 0.8666 - mean_squared_error: 0.0989 - auc: 0.8704 - 143ms/epoch - 2ms/step
# Epoch 79/200
# 80/80 - 0s - loss: 0.3259 - accuracy: 0.8644 - mean_squared_error: 0.0990 - auc: 0.8702 - 133ms/epoch - 2ms/step
# Epoch 80/200
# 80/80 - 0s - loss: 0.3249 - accuracy: 0.8646 - mean_squared_error: 0.0988 - auc: 0.8712 - 136ms/epoch - 2ms/step
# Epoch 81/200
# 80/80 - 0s - loss: 0.3250 - accuracy: 0.8686 - mean_squared_error: 0.0987 - auc: 0.8704 - 129ms/epoch - 2ms/step
# Epoch 82/200
# 80/80 - 0s - loss: 0.3240 - accuracy: 0.8656 - mean_squared_error: 0.0985 - auc: 0.8716 - 131ms/epoch - 2ms/step
# Epoch 83/200
# 80/80 - 0s - loss: 0.3244 - accuracy: 0.8654 - mean_squared_error: 0.0986 - auc: 0.8709 - 137ms/epoch - 2ms/step
# Epoch 84/200
# 80/80 - 0s - loss: 0.3243 - accuracy: 0.8659 - mean_squared_error: 0.0987 - auc: 0.8715 - 158ms/epoch - 2ms/step
# Epoch 85/200
# 80/80 - 0s - loss: 0.3241 - accuracy: 0.8655 - mean_squared_error: 0.0984 - auc: 0.8718 - 161ms/epoch - 2ms/step
# Epoch 86/200
# 80/80 - 0s - loss: 0.3237 - accuracy: 0.8664 - mean_squared_error: 0.0984 - auc: 0.8718 - 151ms/epoch - 2ms/step
# Epoch 87/200
# 80/80 - 0s - loss: 0.3233 - accuracy: 0.8676 - mean_squared_error: 0.0981 - auc: 0.8720 - 141ms/epoch - 2ms/step
# Epoch 88/200
# 80/80 - 0s - loss: 0.3241 - accuracy: 0.8671 - mean_squared_error: 0.0984 - auc: 0.8715 - 141ms/epoch - 2ms/step
# Epoch 89/200
# 80/80 - 0s - loss: 0.3254 - accuracy: 0.8674 - mean_squared_error: 0.0989 - auc: 0.8706 - 143ms/epoch - 2ms/step
# Epoch 90/200
# 80/80 - 0s - loss: 0.3232 - accuracy: 0.8664 - mean_squared_error: 0.0983 - auc: 0.8722 - 147ms/epoch - 2ms/step
# Epoch 91/200
# 80/80 - 0s - loss: 0.3237 - accuracy: 0.8651 - mean_squared_error: 0.0983 - auc: 0.8722 - 148ms/epoch - 2ms/step
# Epoch 92/200
# 80/80 - 0s - loss: 0.3223 - accuracy: 0.8679 - mean_squared_error: 0.0977 - auc: 0.8726 - 138ms/epoch - 2ms/step
# Epoch 93/200
# 80/80 - 0s - loss: 0.3229 - accuracy: 0.8680 - mean_squared_error: 0.0981 - auc: 0.8722 - 139ms/epoch - 2ms/step
# Epoch 94/200
# 80/80 - 0s - loss: 0.3232 - accuracy: 0.8673 - mean_squared_error: 0.0982 - auc: 0.8729 - 131ms/epoch - 2ms/step
# Epoch 95/200
# 80/80 - 0s - loss: 0.3222 - accuracy: 0.8670 - mean_squared_error: 0.0980 - auc: 0.8731 - 145ms/epoch - 2ms/step
# Epoch 96/200
# 80/80 - 0s - loss: 0.3224 - accuracy: 0.8676 - mean_squared_error: 0.0979 - auc: 0.8732 - 131ms/epoch - 2ms/step
# Epoch 97/200
# 80/80 - 0s - loss: 0.3224 - accuracy: 0.8674 - mean_squared_error: 0.0979 - auc: 0.8727 - 139ms/epoch - 2ms/step
# Epoch 98/200
# 80/80 - 0s - loss: 0.3216 - accuracy: 0.8676 - mean_squared_error: 0.0978 - auc: 0.8742 - 160ms/epoch - 2ms/step
# Epoch 99/200
# 80/80 - 0s - loss: 0.3215 - accuracy: 0.8684 - mean_squared_error: 0.0975 - auc: 0.8738 - 158ms/epoch - 2ms/step
# Epoch 100/200
# 80/80 - 0s - loss: 0.3223 - accuracy: 0.8681 - mean_squared_error: 0.0978 - auc: 0.8731 - 147ms/epoch - 2ms/step
# Epoch 101/200
# 80/80 - 0s - loss: 0.3219 - accuracy: 0.8666 - mean_squared_error: 0.0978 - auc: 0.8737 - 136ms/epoch - 2ms/step
# Epoch 102/200
# 80/80 - 0s - loss: 0.3215 - accuracy: 0.8662 - mean_squared_error: 0.0976 - auc: 0.8740 - 148ms/epoch - 2ms/step
# Epoch 103/200
# 80/80 - 0s - loss: 0.3209 - accuracy: 0.8666 - mean_squared_error: 0.0974 - auc: 0.8747 - 140ms/epoch - 2ms/step
# Epoch 104/200
# 80/80 - 0s - loss: 0.3210 - accuracy: 0.8685 - mean_squared_error: 0.0976 - auc: 0.8746 - 154ms/epoch - 2ms/step
# Epoch 105/200
# 80/80 - 0s - loss: 0.3209 - accuracy: 0.8671 - mean_squared_error: 0.0974 - auc: 0.8743 - 152ms/epoch - 2ms/step
# Epoch 106/200
# 80/80 - 0s - loss: 0.3207 - accuracy: 0.8676 - mean_squared_error: 0.0975 - auc: 0.8751 - 148ms/epoch - 2ms/step
# Epoch 107/200
# 80/80 - 0s - loss: 0.3203 - accuracy: 0.8679 - mean_squared_error: 0.0973 - auc: 0.8754 - 149ms/epoch - 2ms/step
# Epoch 108/200
# 80/80 - 0s - loss: 0.3209 - accuracy: 0.8677 - mean_squared_error: 0.0976 - auc: 0.8744 - 137ms/epoch - 2ms/step
# Epoch 109/200
# 80/80 - 0s - loss: 0.3208 - accuracy: 0.8668 - mean_squared_error: 0.0975 - auc: 0.8751 - 137ms/epoch - 2ms/step
# Epoch 110/200
# 80/80 - 0s - loss: 0.3202 - accuracy: 0.8698 - mean_squared_error: 0.0971 - auc: 0.8754 - 133ms/epoch - 2ms/step
# Epoch 111/200
# 80/80 - 0s - loss: 0.3201 - accuracy: 0.8691 - mean_squared_error: 0.0971 - auc: 0.8755 - 148ms/epoch - 2ms/step
# Epoch 112/200
# 80/80 - 0s - loss: 0.3201 - accuracy: 0.8677 - mean_squared_error: 0.0972 - auc: 0.8752 - 142ms/epoch - 2ms/step
# Epoch 113/200
# 80/80 - 0s - loss: 0.3207 - accuracy: 0.8691 - mean_squared_error: 0.0974 - auc: 0.8749 - 131ms/epoch - 2ms/step
# Epoch 114/200
# 80/80 - 0s - loss: 0.3200 - accuracy: 0.8691 - mean_squared_error: 0.0971 - auc: 0.8755 - 134ms/epoch - 2ms/step
# Epoch 115/200
# 80/80 - 0s - loss: 0.3187 - accuracy: 0.8686 - mean_squared_error: 0.0968 - auc: 0.8765 - 133ms/epoch - 2ms/step
# Epoch 116/200
# 80/80 - 0s - loss: 0.3197 - accuracy: 0.8685 - mean_squared_error: 0.0971 - auc: 0.8761 - 144ms/epoch - 2ms/step
# Epoch 117/200
# 80/80 - 0s - loss: 0.3197 - accuracy: 0.8696 - mean_squared_error: 0.0969 - auc: 0.8754 - 134ms/epoch - 2ms/step
# Epoch 118/200
# 80/80 - 0s - loss: 0.3180 - accuracy: 0.8694 - mean_squared_error: 0.0964 - auc: 0.8768 - 147ms/epoch - 2ms/step
# Epoch 119/200
# 80/80 - 0s - loss: 0.3192 - accuracy: 0.8680 - mean_squared_error: 0.0969 - auc: 0.8757 - 145ms/epoch - 2ms/step
# Epoch 120/200
# 80/80 - 0s - loss: 0.3191 - accuracy: 0.8704 - mean_squared_error: 0.0969 - auc: 0.8761 - 137ms/epoch - 2ms/step
# Epoch 121/200
# 80/80 - 0s - loss: 0.3184 - accuracy: 0.8694 - mean_squared_error: 0.0967 - auc: 0.8767 - 131ms/epoch - 2ms/step
# Epoch 122/200
# 80/80 - 0s - loss: 0.3180 - accuracy: 0.8684 - mean_squared_error: 0.0965 - auc: 0.8770 - 130ms/epoch - 2ms/step
# Epoch 123/200
# 80/80 - 0s - loss: 0.3187 - accuracy: 0.8671 - mean_squared_error: 0.0967 - auc: 0.8767 - 132ms/epoch - 2ms/step
# Epoch 124/200
# 80/80 - 0s - loss: 0.3180 - accuracy: 0.8668 - mean_squared_error: 0.0966 - auc: 0.8770 - 136ms/epoch - 2ms/step
# Epoch 125/200
# 80/80 - 0s - loss: 0.3176 - accuracy: 0.8692 - mean_squared_error: 0.0964 - auc: 0.8774 - 179ms/epoch - 2ms/step
# Epoch 126/200
# 80/80 - 0s - loss: 0.3183 - accuracy: 0.8690 - mean_squared_error: 0.0968 - auc: 0.8778 - 160ms/epoch - 2ms/step
# Epoch 127/200
# 80/80 - 0s - loss: 0.3189 - accuracy: 0.8685 - mean_squared_error: 0.0969 - auc: 0.8760 - 134ms/epoch - 2ms/step
# Epoch 128/200
# 80/80 - 0s - loss: 0.3177 - accuracy: 0.8704 - mean_squared_error: 0.0964 - auc: 0.8773 - 139ms/epoch - 2ms/step
# Epoch 129/200
# 80/80 - 0s - loss: 0.3172 - accuracy: 0.8701 - mean_squared_error: 0.0962 - auc: 0.8775 - 141ms/epoch - 2ms/step
# Epoch 130/200
# 80/80 - 0s - loss: 0.3183 - accuracy: 0.8691 - mean_squared_error: 0.0965 - auc: 0.8762 - 137ms/epoch - 2ms/step
# Epoch 131/200
# 80/80 - 0s - loss: 0.3166 - accuracy: 0.8702 - mean_squared_error: 0.0961 - auc: 0.8786 - 138ms/epoch - 2ms/step
# Epoch 132/200
# 80/80 - 0s - loss: 0.3179 - accuracy: 0.8684 - mean_squared_error: 0.0966 - auc: 0.8773 - 151ms/epoch - 2ms/step
# Epoch 133/200
# 80/80 - 0s - loss: 0.3180 - accuracy: 0.8696 - mean_squared_error: 0.0965 - auc: 0.8771 - 138ms/epoch - 2ms/step
# Epoch 134/200
# 80/80 - 0s - loss: 0.3173 - accuracy: 0.8685 - mean_squared_error: 0.0961 - auc: 0.8774 - 165ms/epoch - 2ms/step
# Epoch 135/200
# 80/80 - 0s - loss: 0.3173 - accuracy: 0.8701 - mean_squared_error: 0.0964 - auc: 0.8779 - 136ms/epoch - 2ms/step
# Epoch 136/200
# 80/80 - 0s - loss: 0.3175 - accuracy: 0.8694 - mean_squared_error: 0.0963 - auc: 0.8774 - 136ms/epoch - 2ms/step
# Epoch 137/200
# 80/80 - 0s - loss: 0.3165 - accuracy: 0.8719 - mean_squared_error: 0.0959 - auc: 0.8783 - 142ms/epoch - 2ms/step
# Epoch 138/200
# 80/80 - 0s - loss: 0.3168 - accuracy: 0.8695 - mean_squared_error: 0.0962 - auc: 0.8786 - 133ms/epoch - 2ms/step
# Epoch 139/200
# 80/80 - 0s - loss: 0.3158 - accuracy: 0.8694 - mean_squared_error: 0.0958 - auc: 0.8789 - 149ms/epoch - 2ms/step
# Epoch 140/200
# 80/80 - 0s - loss: 0.3166 - accuracy: 0.8695 - mean_squared_error: 0.0961 - auc: 0.8781 - 135ms/epoch - 2ms/step
# Epoch 141/200
# 80/80 - 0s - loss: 0.3171 - accuracy: 0.8701 - mean_squared_error: 0.0959 - auc: 0.8768 - 134ms/epoch - 2ms/step
# Epoch 142/200
# 80/80 - 0s - loss: 0.3163 - accuracy: 0.8706 - mean_squared_error: 0.0961 - auc: 0.8792 - 137ms/epoch - 2ms/step
# Epoch 143/200
# 80/80 - 0s - loss: 0.3168 - accuracy: 0.8701 - mean_squared_error: 0.0962 - auc: 0.8784 - 126ms/epoch - 2ms/step
# Epoch 144/200
# 80/80 - 0s - loss: 0.3157 - accuracy: 0.8705 - mean_squared_error: 0.0958 - auc: 0.8792 - 137ms/epoch - 2ms/step
# Epoch 145/200
# 80/80 - 0s - loss: 0.3163 - accuracy: 0.8708 - mean_squared_error: 0.0959 - auc: 0.8788 - 128ms/epoch - 2ms/step
# Epoch 146/200
# 80/80 - 0s - loss: 0.3151 - accuracy: 0.8700 - mean_squared_error: 0.0956 - auc: 0.8793 - 141ms/epoch - 2ms/step
# Epoch 147/200
# 80/80 - 0s - loss: 0.3171 - accuracy: 0.8709 - mean_squared_error: 0.0961 - auc: 0.8782 - 130ms/epoch - 2ms/step
# Epoch 148/200
# 80/80 - 0s - loss: 0.3155 - accuracy: 0.8710 - mean_squared_error: 0.0957 - auc: 0.8786 - 133ms/epoch - 2ms/step
# Epoch 149/200
# 80/80 - 0s - loss: 0.3146 - accuracy: 0.8711 - mean_squared_error: 0.0954 - auc: 0.8802 - 132ms/epoch - 2ms/step
# Epoch 150/200
# 80/80 - 0s - loss: 0.3153 - accuracy: 0.8702 - mean_squared_error: 0.0956 - auc: 0.8795 - 132ms/epoch - 2ms/step
# Epoch 151/200
# 80/80 - 0s - loss: 0.3144 - accuracy: 0.8710 - mean_squared_error: 0.0954 - auc: 0.8804 - 122ms/epoch - 2ms/step
# Epoch 152/200
# 80/80 - 0s - loss: 0.3149 - accuracy: 0.8694 - mean_squared_error: 0.0955 - auc: 0.8799 - 130ms/epoch - 2ms/step
# Epoch 153/200
# 80/80 - 0s - loss: 0.3144 - accuracy: 0.8723 - mean_squared_error: 0.0953 - auc: 0.8804 - 142ms/epoch - 2ms/step
# Epoch 154/200
# 80/80 - 0s - loss: 0.3141 - accuracy: 0.8715 - mean_squared_error: 0.0952 - auc: 0.8802 - 137ms/epoch - 2ms/step
# Epoch 155/200
# 80/80 - 0s - loss: 0.3145 - accuracy: 0.8717 - mean_squared_error: 0.0955 - auc: 0.8802 - 137ms/epoch - 2ms/step
# Epoch 156/200
# 80/80 - 0s - loss: 0.3144 - accuracy: 0.8719 - mean_squared_error: 0.0953 - auc: 0.8802 - 129ms/epoch - 2ms/step
# Epoch 157/200
# 80/80 - 0s - loss: 0.3151 - accuracy: 0.8696 - mean_squared_error: 0.0958 - auc: 0.8797 - 141ms/epoch - 2ms/step
# Epoch 158/200
# 80/80 - 0s - loss: 0.3144 - accuracy: 0.8733 - mean_squared_error: 0.0952 - auc: 0.8801 - 128ms/epoch - 2ms/step
# Epoch 159/200
# 80/80 - 0s - loss: 0.3144 - accuracy: 0.8717 - mean_squared_error: 0.0955 - auc: 0.8806 - 132ms/epoch - 2ms/step
# Epoch 160/200
# 80/80 - 0s - loss: 0.3129 - accuracy: 0.8714 - mean_squared_error: 0.0949 - auc: 0.8815 - 138ms/epoch - 2ms/step
# Epoch 161/200
# 80/80 - 0s - loss: 0.3138 - accuracy: 0.8708 - mean_squared_error: 0.0954 - auc: 0.8806 - 142ms/epoch - 2ms/step
# Epoch 162/200
# 80/80 - 0s - loss: 0.3141 - accuracy: 0.8700 - mean_squared_error: 0.0954 - auc: 0.8808 - 134ms/epoch - 2ms/step
# Epoch 163/200
# 80/80 - 0s - loss: 0.3138 - accuracy: 0.8731 - mean_squared_error: 0.0952 - auc: 0.8808 - 127ms/epoch - 2ms/step
# Epoch 164/200
# 80/80 - 0s - loss: 0.3149 - accuracy: 0.8712 - mean_squared_error: 0.0956 - auc: 0.8796 - 137ms/epoch - 2ms/step
# Epoch 165/200
# 80/80 - 0s - loss: 0.3138 - accuracy: 0.8709 - mean_squared_error: 0.0951 - auc: 0.8805 - 130ms/epoch - 2ms/step
# Epoch 166/200
# 80/80 - 0s - loss: 0.3136 - accuracy: 0.8723 - mean_squared_error: 0.0951 - auc: 0.8808 - 134ms/epoch - 2ms/step
# Epoch 167/200
# 80/80 - 0s - loss: 0.3131 - accuracy: 0.8726 - mean_squared_error: 0.0949 - auc: 0.8809 - 146ms/epoch - 2ms/step
# Epoch 168/200
# 80/80 - 0s - loss: 0.3139 - accuracy: 0.8704 - mean_squared_error: 0.0952 - auc: 0.8804 - 166ms/epoch - 2ms/step
# Epoch 169/200
# 80/80 - 0s - loss: 0.3135 - accuracy: 0.8719 - mean_squared_error: 0.0950 - auc: 0.8810 - 140ms/epoch - 2ms/step
# Epoch 170/200
# 80/80 - 0s - loss: 0.3139 - accuracy: 0.8716 - mean_squared_error: 0.0951 - auc: 0.8801 - 133ms/epoch - 2ms/step
# Epoch 171/200
# 80/80 - 0s - loss: 0.3131 - accuracy: 0.8731 - mean_squared_error: 0.0950 - auc: 0.8813 - 140ms/epoch - 2ms/step
# Epoch 172/200
# 80/80 - 0s - loss: 0.3128 - accuracy: 0.8720 - mean_squared_error: 0.0949 - auc: 0.8817 - 141ms/epoch - 2ms/step
# Epoch 173/200
# 80/80 - 0s - loss: 0.3129 - accuracy: 0.8721 - mean_squared_error: 0.0950 - auc: 0.8811 - 134ms/epoch - 2ms/step
# Epoch 174/200
# 80/80 - 0s - loss: 0.3136 - accuracy: 0.8726 - mean_squared_error: 0.0950 - auc: 0.8806 - 144ms/epoch - 2ms/step
# Epoch 175/200
# 80/80 - 0s - loss: 0.3128 - accuracy: 0.8709 - mean_squared_error: 0.0946 - auc: 0.8816 - 152ms/epoch - 2ms/step
# Epoch 176/200
# 80/80 - 0s - loss: 0.3134 - accuracy: 0.8705 - mean_squared_error: 0.0953 - auc: 0.8815 - 135ms/epoch - 2ms/step
# Epoch 177/200
# 80/80 - 0s - loss: 0.3126 - accuracy: 0.8702 - mean_squared_error: 0.0948 - auc: 0.8816 - 147ms/epoch - 2ms/step
# Epoch 178/200
# 80/80 - 0s - loss: 0.3130 - accuracy: 0.8729 - mean_squared_error: 0.0947 - auc: 0.8811 - 134ms/epoch - 2ms/step
# Epoch 179/200
# 80/80 - 0s - loss: 0.3135 - accuracy: 0.8735 - mean_squared_error: 0.0950 - auc: 0.8806 - 143ms/epoch - 2ms/step
# Epoch 180/200
# 80/80 - 0s - loss: 0.3125 - accuracy: 0.8721 - mean_squared_error: 0.0947 - auc: 0.8820 - 162ms/epoch - 2ms/step
# Epoch 181/200
# 80/80 - 0s - loss: 0.3113 - accuracy: 0.8723 - mean_squared_error: 0.0944 - auc: 0.8826 - 144ms/epoch - 2ms/step
# Epoch 182/200
# 80/80 - 0s - loss: 0.3119 - accuracy: 0.8715 - mean_squared_error: 0.0946 - auc: 0.8820 - 134ms/epoch - 2ms/step
# Epoch 183/200
# 80/80 - 0s - loss: 0.3102 - accuracy: 0.8716 - mean_squared_error: 0.0941 - auc: 0.8839 - 128ms/epoch - 2ms/step
# Epoch 184/200
# 80/80 - 0s - loss: 0.3118 - accuracy: 0.8727 - mean_squared_error: 0.0945 - auc: 0.8822 - 131ms/epoch - 2ms/step
# Epoch 185/200
# 80/80 - 0s - loss: 0.3118 - accuracy: 0.8723 - mean_squared_error: 0.0943 - auc: 0.8823 - 135ms/epoch - 2ms/step
# Epoch 186/200
# 80/80 - 0s - loss: 0.3117 - accuracy: 0.8735 - mean_squared_error: 0.0945 - auc: 0.8824 - 133ms/epoch - 2ms/step
# Epoch 187/200
# 80/80 - 0s - loss: 0.3112 - accuracy: 0.8719 - mean_squared_error: 0.0943 - auc: 0.8828 - 135ms/epoch - 2ms/step
# Epoch 188/200
# 80/80 - 0s - loss: 0.3104 - accuracy: 0.8725 - mean_squared_error: 0.0941 - auc: 0.8835 - 146ms/epoch - 2ms/step
# Epoch 189/200
# 80/80 - 0s - loss: 0.3114 - accuracy: 0.8725 - mean_squared_error: 0.0943 - auc: 0.8823 - 162ms/epoch - 2ms/step
# Epoch 190/200
# 80/80 - 0s - loss: 0.3110 - accuracy: 0.8726 - mean_squared_error: 0.0943 - auc: 0.8838 - 136ms/epoch - 2ms/step
# Epoch 191/200
# 80/80 - 0s - loss: 0.3104 - accuracy: 0.8721 - mean_squared_error: 0.0943 - auc: 0.8843 - 149ms/epoch - 2ms/step
# Epoch 192/200
# 80/80 - 0s - loss: 0.3110 - accuracy: 0.8720 - mean_squared_error: 0.0942 - auc: 0.8833 - 145ms/epoch - 2ms/step
# Epoch 193/200
# 80/80 - 0s - loss: 0.3110 - accuracy: 0.8730 - mean_squared_error: 0.0942 - auc: 0.8830 - 137ms/epoch - 2ms/step
# Epoch 194/200
# 80/80 - 0s - loss: 0.3098 - accuracy: 0.8727 - mean_squared_error: 0.0938 - auc: 0.8839 - 151ms/epoch - 2ms/step
# Epoch 195/200
# 80/80 - 0s - loss: 0.3115 - accuracy: 0.8735 - mean_squared_error: 0.0941 - auc: 0.8826 - 148ms/epoch - 2ms/step
# Epoch 196/200
# 80/80 - 0s - loss: 0.3101 - accuracy: 0.8729 - mean_squared_error: 0.0941 - auc: 0.8839 - 130ms/epoch - 2ms/step
# Epoch 197/200
# 80/80 - 0s - loss: 0.3093 - accuracy: 0.8727 - mean_squared_error: 0.0937 - auc: 0.8846 - 131ms/epoch - 2ms/step
# Epoch 198/200
# 80/80 - 0s - loss: 0.3105 - accuracy: 0.8726 - mean_squared_error: 0.0940 - auc: 0.8833 - 134ms/epoch - 2ms/step
# Epoch 199/200
# 80/80 - 0s - loss: 0.3107 - accuracy: 0.8737 - mean_squared_error: 0.0941 - auc: 0.8838 - 134ms/epoch - 2ms/step
# Epoch 200/200
# 80/80 - 0s - loss: 0.3112 - accuracy: 0.8729 - mean_squared_error: 0.0943 - auc: 0.8831 - 129ms/epoch - 2ms/step
# Tag : 'NeuralNetwork trained on basic data'
# Model name : KerasClassifier(
# 	model=<function model_nn at 0x7f0cbf098440>
# 	build_fn=None
# 	warm_start=False
# 	random_state=None
# 	optimizer=rmsprop
# 	loss=None
# 	metrics=None
# 	batch_size=100
# 	validation_batch_size=None
# 	verbose=2
# 	callbacks=None
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=200
# 	class_weight=None
# )
# ModelWrapper(base_model=KerasClassifier(batch_size=100, epochs=200, model=<function model_nn at 0x7f0cbf098440>, verbose=2), base_preprocessor=ColumnTransformer(transformers=[('pipeline-1', Pipeline(steps=[('simpleimputer', SimpleImputer()), ('standardscaler', StandardScaler())]), ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']), ('pi...cts', 'EstimatedSalary']), ('pipeline-2', Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')), ('ordinalencoder', OrdinalEncoder())]), ['HasCrCard', 'IsActiveMember', 'Geography', 'Gender'])])), ('model', KerasClassifier(batch_size=100, epochs=200, model=<function model_nn at 0x7f0cbf098440>, verbose=2))], tag='NeuralNetwork trained on basic data')

# %%
model5_predictions = model5.predict(df_test_x)
# Out:
# 20/20 - 0s - 110ms/epoch - 5ms/step

# %%
model5.evaluate(y_true = df_test_y, y_pred = model5_predictions)
# Out:
# Confusion matrix : array([[1534,   51],
#        [ 210,  205]])
# Precision : 0.80078125
# Accuracy : 0.8695
# Recall : 0.4939759036144578

# %%
model5.calculate_roc(y_true = df_test_y, y_score = model5.predict_proba(df_test_x)[:,1])
# Out:
# 20/20 - 0s - 39ms/epoch - 2ms/step
# Roc_auc_score : 0.8632967200030406

# %%
list_of_models.append(model5)

# %% [markdown]
# # 5.Summary of all models

# %% [markdown]
# We compare now the performances of the different tested models

# %%
global_report = pd.DataFrame(columns = ['Tag', 'Description' , 'Confusion matrix', 'Accuracy', 'Precision', 'Recall', 'ROC'])

plt.figure(figsize = (12,6), linewidth= 1)
plt.plot([0,1], [0,1], 'k--', label = 'Random: 0.5')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC Curve')

for model in list_of_models:
  global_report = global_report.append(model.get_performances(),ignore_index = True)
  plt.plot(model.fpr, model.tpr, label=str(model.tag) + ", AUC=" + str(model.roc_auc_score))

plt.legend(loc='best')

# %%
global_report
# Out:
#                                         Tag  \
# 0       XGBClassifier trained on basic data
# 1  LogisticRegression trained on basic data
# 2                 SVM trained on basic data
# 3        RandomForest trained on basic data
# 4       NeuralNetwork trained on basic data
#
#                                          Description  \
# 0  GridSearchCV(cv=5, estimator=XGBClassifier(),\...
# 1  GridSearchCV(cv=10, estimator=LogisticRegressi...
# 2  GridSearchCV(cv=3, estimator=SVC(),\n         ...
# 3  GridSearchCV(cv=5, estimator=RandomForestClass...
# 4  KerasClassifier(\n\tmodel=<function model_nn a...
#
#            Confusion matrix  Accuracy  Precision    Recall       ROC
# 0  [[1538, 47], [233, 182]]    0.8600   0.794760  0.438554  0.869225
# 1   [[1536, 49], [339, 76]]    0.8060   0.608000  0.183133  0.760962
# 2  [[1567, 18], [274, 141]]    0.8540   0.886792  0.339759  0.833153
# 3  [[1545, 40], [240, 175]]    0.8600   0.813953  0.421687  0.872555
# 4  [[1534, 51], [210, 205]]    0.8695   0.800781  0.493976  0.863297

# %% [markdown]
# For the moment, the XGBClassifier and the RandomForest seem to be the best with very similar performances. There is a little better recall for the XGBClassifier which is the most important, since we want to identify a maximum of the clients who are likely to exit.

# %% [markdown]
# # 6.Saving the models

# %% [markdown]
# We save now the different models to be able to use them in the future prediction application

# %%
import os
import pickle

path_for_models_trained_on_basic_data = '/content/drive/MyDrive/Colab Notebooks/projet/trained models basic/'

for model in list_of_models:
  
  try:
    os.remove(path_for_models_trained_on_basic_data + model.tag + '.sav')
    print(path_for_models_trained_on_basic_data + model.tag + '.sav has been deleted')
  except:
    print(model.tag + ' does not exist')

  with open(path_for_models_trained_on_basic_data + model.tag + '.sav', 'wb') as f:

    pickle.dump(model, f)
    f.close()

    print(path_for_models_trained_on_basic_data + model.tag + '.sav has been saved')
# Out:
# /content/drive/MyDrive/Colab Notebooks/projet/trained models basic/XGBClassifier trained on basic data.sav has been deleted
# /content/drive/MyDrive/Colab Notebooks/projet/trained models basic/XGBClassifier trained on basic data.sav has been saved
# /content/drive/MyDrive/Colab Notebooks/projet/trained models basic/LogisticRegression trained on basic data.sav has been deleted
# /content/drive/MyDrive/Colab Notebooks/projet/trained models basic/LogisticRegression trained on basic data.sav has been saved
# /content/drive/MyDrive/Colab Notebooks/projet/trained models basic/SVM trained on basic data.sav has been deleted
# /content/drive/MyDrive/Colab Notebooks/projet/trained models basic/SVM trained on basic data.sav has been saved
# /content/drive/MyDrive/Colab Notebooks/projet/trained models basic/RandomForest trained on basic data.sav has been deleted
# /content/drive/MyDrive/Colab Notebooks/projet/trained models basic/RandomForest trained on basic data.sav has been saved
# /content/drive/MyDrive/Colab Notebooks/projet/trained models basic/NeuralNetwork trained on basic data.sav has been deleted
# /content/drive/MyDrive/Colab Notebooks/projet/trained models basic/NeuralNetwork trained on basic data.sav has been saved
